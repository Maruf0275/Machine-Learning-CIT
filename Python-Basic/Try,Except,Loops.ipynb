# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf0275/Machine-Learning-CIT/blob/main/Python-Basic/Try%2CExcept%2CLoops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Try Except

# %%
try:
  a = int(input("Enter the number: "))
  print(f"Multiplication table of {a} is: ")
  i = 1
  while i <= 10:
    print(f"{a} * {i} = {a * i}")
    i+=1
except Exception as e:
  print(e)
print("Over")
# Out:
# Enter the number: maruf
# invalid literal for int() with base 10: 'maruf'
# Over

# %%
# Finally Keyword
try:
  l = [1,2,3,4]
  i = int(input("Enter the index number: "))
  print(l[i])
except:
  print("Some Error Occured")
finally:
  print("I am always Executed")
# Out:
# Enter the index number: 5
# Some Error Occured
# I am always Executed

# %% [markdown]
# ## While loop
