# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf0275/Machine-Learning-CIT/blob/main/Python-Basic/Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise

# %%
print('Hello')
# Out:
# Hello

# %%
x = True
y = 1

print(x==y)
print(x is y)
# Out:
# True
# False

# %%
a = -10
print(bool(a))
# Out:
# True

# %%
print(bool(''))
# Out:
# False

# %% [markdown]
# ##Opertator
